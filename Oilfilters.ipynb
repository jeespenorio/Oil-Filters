# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import os
import psycopg2

# %%
import pandas as pd

path = r"C:\Users\User\Desktop\nachmann\Oil Filters\Automatic_Distributors_Oil_Filters.csv"
df = pd.read_csv(path, encoding='utf-8-sig')
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[11], line 4
#       1 import pandas as pd
#       3 path = r"C:\Users\User\Desktop\nachmann\Oil Filters\Automatic_Distributors_Oil_Filters.csv"
# ----> 4 df = pd.read_csv(path, encoding='utf-8-sig')
#       5 df.head(10)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1753, in TextFileReader._make_engine(self, f, engine)
#    1750     raise ValueError(msg)
#    1752 try:
# -> 1753     return mapping[engine](f, **self.options)
#    1754 except Exception:
#    1755     if self.handles is not None:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:79, in CParserWrapper.__init__(self, src, **kwds)
#      76     kwds.pop(key, None)
#      78 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 79 self._reader = parsers.TextReader(src, **kwds)
#      81 self.unnamed_cols = self._reader.unnamed_cols
#      83 # error: Cannot determine type of 'names'
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\parsers.pyx:547, in pandas._libs.parsers.TextReader.__cinit__()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\parsers.pyx:636, in pandas._libs.parsers.TextReader._get_header()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\parsers.pyx:852, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\parsers.pyx:1965, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa0 in position 8434: invalid start byte

# %% [markdown]
# Sol:

# %%
import pandas as pd

path = r"C:\Users\User\Desktop\nachmann\Oil Filters\Automatic_Distributors_Oil_Filters.csv"
try:
    df = pd.read_csv(path, encoding='latin1')
except UnicodeDecodeError:
    df = pd.read_csv(path, encoding='cp1252')
df.head(10)
# Out:
#       Make                                          Model    Year Vendor  \
# 0     LYNX                                69 YETI 900 ACE  2015.0   NACH
# 1     LYNX                                69 YETI 900 ACE  2015.0   NACH
# 2     LYNX                                69 YETI 900 ACE  2015.0   NACH
# 3  SKI-DOO     EXPEDITION 600R E-TEC LE 20 INCH / 24 INCH  2023.0   NACH
# 4  SKI-DOO     EXPEDITION 600R E-TEC LE 20 INCH / 24 INCH  2023.0   NACH
# 5  SKI-DOO     EXPEDITION 600R E-TEC LE 20 INCH / 24 INCH  2023.0   NACH
# 6  SKI-DOO        EXPEDITION 900 ACE LE 20 INCH / 24 INCH  2023.0   NACH
# 7  SKI-DOO        EXPEDITION 900 ACE LE 20 INCH / 24 INCH  2023.0   NACH
# 8  SKI-DOO        EXPEDITION 900 ACE LE 20 INCH / 24 INCH  2023.0   NACH
# 9  SKI-DOO  EXPEDITION 900 ACE TURBO LE 20 INCH / 24 INCH  2023.0   NACH
#
#         MPN AD Item Number      NI#        OEM# REF#     O.D  I.D HEIGHT  \
# 0  SM-07163         120322  SM-07163  420956120  NaN  56.6MM  NaN   74MM
# 1  SM-07163         120322  SM-07163  420956123  NaN  56.6MM  NaN   74MM
# 2  SM-07163         120322  SM-07163  420956124  NaN  56.6MM  NaN   74MM
# 3  SM-07163         120322  SM-07163  420956120  NaN  56.6MM  NaN   74MM
# 4  SM-07163         120322  SM-07163  420956123  NaN  56.6MM  NaN   74MM
# 5  SM-07163         120322  SM-07163  420956124  NaN  56.6MM  NaN   74MM
# 6  SM-07163         120322  SM-07163  420956120  NaN  56.6MM  NaN   74MM
# 7  SM-07163         120322  SM-07163  420956123  NaN  56.6MM  NaN   74MM
# 8  SM-07163         120322  SM-07163  420956124  NaN  56.6MM  NaN   74MM
# 9  SM-07163         120322  SM-07163  420956120  NaN  56.6MM  NaN   74MM
#
#                      Vendor Notes
# 0  PAPER ELEMENT TYPE WITH O-RING
# 1  PAPER ELEMENT TYPE WITH O-RING
# 2  PAPER ELEMENT TYPE WITH O-RING
# 3  PAPER ELEMENT TYPE WITH O-RING
# 4  PAPER ELEMENT TYPE WITH O-RING
# 5  PAPER ELEMENT TYPE WITH O-RING
# 6  PAPER ELEMENT TYPE WITH O-RING
# 7  PAPER ELEMENT TYPE WITH O-RING
# 8  PAPER ELEMENT TYPE WITH O-RING
# 9  PAPER ELEMENT TYPE WITH O-RING

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor': ['NACH'], 'MPN': ['AT-07063'], 'AD Item Number': ['KX09402'], 
         'Vendor Notes': ['WITH O-RING'], 'NI#': ['AT-07063'], 'REF#': ['KN-196'], 'OEM#': ['2540006','2540086']}

# List of models
new_list_models = [
"FRONTIER CLASSIC",
"INDY FRONTIER",
"FRONTIER TOURING"
]

oem_numbers = ['2540006', '2540086']

# Range of years
years = list(range(2003, 2006))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make             Model Vendor       MPN AD Item Number Vendor Notes  \
# 0   POLARIS  FRONTIER CLASSIC   NACH  AT-07063        KX09402  WITH O-RING
# 1   POLARIS     INDY FRONTIER   NACH  AT-07063        KX09402  WITH O-RING
# 2   POLARIS  FRONTIER TOURING   NACH  AT-07063        KX09402  WITH O-RING
# 3   POLARIS  FRONTIER CLASSIC   NACH  AT-07063        KX09402  WITH O-RING
# 4   POLARIS     INDY FRONTIER   NACH  AT-07063        KX09402  WITH O-RING
# 5   POLARIS  FRONTIER TOURING   NACH  AT-07063        KX09402  WITH O-RING
# 6   POLARIS  FRONTIER CLASSIC   NACH  AT-07063        KX09402  WITH O-RING
# 7   POLARIS     INDY FRONTIER   NACH  AT-07063        KX09402  WITH O-RING
# 8   POLARIS  FRONTIER TOURING   NACH  AT-07063        KX09402  WITH O-RING
# 9   POLARIS  FRONTIER CLASSIC   NACH  AT-07063        KX09402  WITH O-RING
# 10  POLARIS     INDY FRONTIER   NACH  AT-07063        KX09402  WITH O-RING
# 11  POLARIS  FRONTIER TOURING   NACH  AT-07063        KX09402  WITH O-RING
# 12  POLARIS  FRONTIER CLASSIC   NACH  AT-07063        KX09402  WITH O-RING
# 13  POLARIS     INDY FRONTIER   NACH  AT-07063        KX09402  WITH O-RING
# 14  POLARIS  FRONTIER TOURING   NACH  AT-07063        KX09402  WITH O-RING
# 15  POLARIS  FRONTIER CLASSIC   NACH  AT-07063        KX09402  WITH O-RING
# 16  POLARIS     INDY FRONTIER   NACH  AT-07063        KX09402  WITH O-RING
# 17  POLARIS  FRONTIER TOURING   NACH  AT-07063        KX09402  WITH O-RING
#
#          NI#    REF#     OEM#  Year
# 0   AT-07063  KN-196  2540006  2003
# 1   AT-07063  KN-196  2540006  2003
# 2   AT-07063  KN-196  2540006  2003
# 3   AT-07063  KN-196  2540086  2003
# 4   AT-07063  KN-196  2540086  2003
# 5   AT-07063  KN-196  2540086  2003
# 6   AT-07063  KN-196  2540006  2004
# 7   AT-07063  KN-196  2540006  2004
# 8   AT-07063  KN-196  2540006  2004
# 9   AT-07063  KN-196  2540086  2004
# 10  AT-07063  KN-196  2540086  2004
# 11  AT-07063  KN-196  2540086  2004
# 12  AT-07063  KN-196  2540006  2005
# 13  AT-07063  KN-196  2540006  2005
# 14  AT-07063  KN-196  2540006  2005
# 15  AT-07063  KN-196  2540086  2005
# 16  AT-07063  KN-196  2540086  2005
# 17  AT-07063  KN-196  2540086  2005

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Oil Filters\MERGE\Oilfilters_frontier04~05.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['ARCTIC CAT'], 'Model': ['all models'], 'Vendor': ['NACH'], 
         'MPN': ['SM-07068'], 'AD Item Number': ['KX09400'], 
         'Vendor Notes': ['WITH O-RING'], 
         'NI#': ['SM-07068'], 'REF#': ['09-4 00'], 'OEM#': ['3005-948']}

# List of models
new_list_models = [
'Bearcat Widetrack',
'Bearcat 570 Long Track',
'Bearcat Widetrack Turbo',
'Bearcat Widetrack Turbo Articulating',
'4-Stroke Touring',
'4-Stroke Trail',
'90 2x4 4-Stroke',
'T660 Touring',
'T660 Turbo Touring',
'T660 Turbo Trail',
'T660 Turbo',
'T660 Turbo ST',
'T660 Turbo ST EFI Early Build',
'T660 Turbo Touring LE',
'T660 Turbo Trail LE'
]

oem_numbers = ['2540006', '2540086']

# Range of years
years = list(range(2003, 2009))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#            Make                                 Model Vendor       MPN  \
# 0    ARCTIC CAT                     Bearcat Widetrack   NACH  SM-07068
# 1    ARCTIC CAT                Bearcat 570 Long Track   NACH  SM-07068
# 2    ARCTIC CAT               Bearcat Widetrack Turbo   NACH  SM-07068
# 3    ARCTIC CAT  Bearcat Widetrack Turbo Articulating   NACH  SM-07068
# 4    ARCTIC CAT                      4-Stroke Touring   NACH  SM-07068
# ..          ...                                   ...    ...       ...
# 175  ARCTIC CAT                            T660 Turbo   NACH  SM-07068
# 176  ARCTIC CAT                         T660 Turbo ST   NACH  SM-07068
# 177  ARCTIC CAT         T660 Turbo ST EFI Early Build   NACH  SM-07068
# 178  ARCTIC CAT                 T660 Turbo Touring LE   NACH  SM-07068
# 179  ARCTIC CAT                   T660 Turbo Trail LE   NACH  SM-07068
#
#     AD Item Number Vendor Notes       NI#     REF#     OEM#  Year
# 0          KX09400  WITH O-RING  SM-07068  09-4 00  2540006  2003
# 1          KX09400  WITH O-RING  SM-07068  09-4 00  2540006  2003
# 2          KX09400  WITH O-RING  SM-07068  09-4 00  2540006  2003
# 3          KX09400  WITH O-RING  SM-07068  09-4 00  2540006  2003
# 4          KX09400  WITH O-RING  SM-07068  09-4 00  2540006  2003
# ..             ...          ...       ...      ...      ...   ...
# 175        KX09400  WITH O-RING  SM-07068  09-4 00  2540086  2008
# 176        KX09400  WITH O-RING  SM-07068  09-4 00  2540086  2008
# 177        KX09400  WITH O-RING  SM-07068  09-4 00  2540086  2008
# 178        KX09400  WITH O-RING  SM-07068  09-4 00  2540086  2008
# 179        KX09400  WITH O-RING  SM-07068  09-4 00  2540086  2008
#
# [180 rows x 10 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Oil Filters\MERGE\Oilfilters_bear4strket6603~09.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 
         'MPN': ['SM-07163'], 'AD Item Number': ['KX09400'], 
         'Vendor Notes': ['PAPER ELEMENT TYPE WITH O-RING'], 
         'NI#': ['SM-07163'], 'REF#': [pd.NA], 'OEM#': ['420956120','420956123','420956124']}

# List of models
new_list_models = [
'Expedition LE E-TEC 600R',
'Expedition SE ACE 900',
'Expedition SE ACE 900 Turbo R',
'Expedition Sport ACE 900',
'Grand Touring Limited ACE 900',
'Grand Touring Limited ACE 900 Turbo',
'Grand Touring Limited ACE 900 Turbo R',
'Grand Touring Sport 600 ACE',
'Grand Touring Sport ACE 900',


]

oem_numbers = ['420956120','420956123','420956124']

# Range of years
years = list(range(2023, 2024))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make                                  Model Vendor       MPN  \
# 0   SKI-DOO               Expedition LE E-TEC 600R   NACH  SM-07163
# 1   SKI-DOO                  Expedition SE ACE 900   NACH  SM-07163
# 2   SKI-DOO          Expedition SE ACE 900 Turbo R   NACH  SM-07163
# 3   SKI-DOO               Expedition Sport ACE 900   NACH  SM-07163
# 4   SKI-DOO          Grand Touring Limited ACE 900   NACH  SM-07163
# 5   SKI-DOO    Grand Touring Limited ACE 900 Turbo   NACH  SM-07163
# 6   SKI-DOO  Grand Touring Limited ACE 900 Turbo R   NACH  SM-07163
# 7   SKI-DOO            Grand Touring Sport 600 ACE   NACH  SM-07163
# 8   SKI-DOO            Grand Touring Sport ACE 900   NACH  SM-07163
# 9   SKI-DOO               Expedition LE E-TEC 600R   NACH  SM-07163
# 10  SKI-DOO                  Expedition SE ACE 900   NACH  SM-07163
# 11  SKI-DOO          Expedition SE ACE 900 Turbo R   NACH  SM-07163
# 12  SKI-DOO               Expedition Sport ACE 900   NACH  SM-07163
# 13  SKI-DOO          Grand Touring Limited ACE 900   NACH  SM-07163
# 14  SKI-DOO    Grand Touring Limited ACE 900 Turbo   NACH  SM-07163
# 15  SKI-DOO  Grand Touring Limited ACE 900 Turbo R   NACH  SM-07163
# 16  SKI-DOO            Grand Touring Sport 600 ACE   NACH  SM-07163
# 17  SKI-DOO            Grand Touring Sport ACE 900   NACH  SM-07163
# 18  SKI-DOO               Expedition LE E-TEC 600R   NACH  SM-07163
# 19  SKI-DOO                  Expedition SE ACE 900   NACH  SM-07163
# 20  SKI-DOO          Expedition SE ACE 900 Turbo R   NACH  SM-07163
# 21  SKI-DOO               Expedition Sport ACE 900   NACH  SM-07163
# 22  SKI-DOO          Grand Touring Limited ACE 900   NACH  SM-07163
# 23  SKI-DOO    Grand Touring Limited ACE 900 Turbo   NACH  SM-07163
# 24  SKI-DOO  Grand Touring Limited ACE 900 Turbo R   NACH  SM-07163
# 25  SKI-DOO            Grand Touring Sport 600 ACE   NACH  SM-07163
# 26  SKI-DOO            Grand Touring Sport ACE 900   NACH  SM-07163
#
#    AD Item Number                    Vendor Notes       NI#  REF#       OEM#  \
# 0         KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120
# 1         KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120
# 2         KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120
# 3         KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120
# 4         KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120
# 5         KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120
# 6         KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120
# 7         KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120
# 8         KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120
# 9         KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123
# 10        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123
# 11        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123
# 12        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123
# 13        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123
# 14        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123
# 15        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123
# 16        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123
# 17        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123
# 18        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124
# 19        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124
# 20        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124
# 21        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124
# 22        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124
# 23        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124
# 24        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124
# 25        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124
# 26        KX09400  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124
#
#     Year
# 0   2023
# 1   2023
# 2   2023
# 3   2023
# 4   2023
# 5   2023
# 6   2023
# 7   2023
# 8   2023
# 9   2023
# 10  2023
# 11  2023
# 12  2023
# 13  2023
# 14  2023
# 15  2023
# 16  2023
# 17  2023
# 18  2023
# 19  2023
# 20  2023
# 21  2023
# 22  2023
# 23  2023
# 24  2023
# 25  2023
# 26  2023

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Oil Filters\MERGE\Oilfilters_23ExpGrandTour.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 
         'MPN': ['SM-07163'], 'AD Item Number': ['KX09400'], 
         'Vendor Notes': ['PAPER ELEMENT TYPE WITH O-RING'], 
         'NI#': ['SM-07163'], 'REF#': [pd.NA], 'OEM#': ['420956120','420956123','420956124']}

# List of models
new_list_models = [
'GSX LE ACE 900',
'GSX LE 4-TEC 1200',
'GSX LE E-TEC 600 HO',
'GSX SE E-TEC 800R',
'GSX SE 4-TEC 1200',
'GSX SE E-TEC 600 HO'


]

oem_numbers = ['420956120','420956123','420956124']

# Range of years
years = list(range(2014, 2015))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#        Make                Model Vendor       MPN AD Item Number  \
# 0   SKI-DOO       GSX LE ACE 900   NACH  SM-07163        KX09400
# 1   SKI-DOO    GSX LE 4-TEC 1200   NACH  SM-07163        KX09400
# 2   SKI-DOO  GSX LE E-TEC 600 HO   NACH  SM-07163        KX09400
# 3   SKI-DOO    GSX SE E-TEC 800R   NACH  SM-07163        KX09400
# 4   SKI-DOO    GSX SE 4-TEC 1200   NACH  SM-07163        KX09400
# 5   SKI-DOO  GSX SE E-TEC 600 HO   NACH  SM-07163        KX09400
# 6   SKI-DOO       GSX LE ACE 900   NACH  SM-07163        KX09400
# 7   SKI-DOO    GSX LE 4-TEC 1200   NACH  SM-07163        KX09400
# 8   SKI-DOO  GSX LE E-TEC 600 HO   NACH  SM-07163        KX09400
# 9   SKI-DOO    GSX SE E-TEC 800R   NACH  SM-07163        KX09400
# 10  SKI-DOO    GSX SE 4-TEC 1200   NACH  SM-07163        KX09400
# 11  SKI-DOO  GSX SE E-TEC 600 HO   NACH  SM-07163        KX09400
# 12  SKI-DOO       GSX LE ACE 900   NACH  SM-07163        KX09400
# 13  SKI-DOO    GSX LE 4-TEC 1200   NACH  SM-07163        KX09400
# 14  SKI-DOO  GSX LE E-TEC 600 HO   NACH  SM-07163        KX09400
# 15  SKI-DOO    GSX SE E-TEC 800R   NACH  SM-07163        KX09400
# 16  SKI-DOO    GSX SE 4-TEC 1200   NACH  SM-07163        KX09400
# 17  SKI-DOO  GSX SE E-TEC 600 HO   NACH  SM-07163        KX09400
#
#                       Vendor Notes       NI#  REF#       OEM#  Year
# 0   PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120  2014
# 1   PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120  2014
# 2   PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120  2014
# 3   PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120  2014
# 4   PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120  2014
# 5   PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120  2014
# 6   PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123  2014
# 7   PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123  2014
# 8   PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123  2014
# 9   PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123  2014
# 10  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123  2014
# 11  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123  2014
# 12  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124  2014
# 13  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124  2014
# 14  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124  2014
# 15  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124  2014
# 16  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124  2014
# 17  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124  2014

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Oil Filters\MERGE\Oilfilters_14gsx.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 
         'MPN': ['SM-07163'], 'AD Item Number': ['KX09400'], 
         'Vendor Notes': ['PAPER ELEMENT TYPE WITH O-RING'], 
         'NI#': ['SM-07163'], 'REF#': [pd.NA], 'OEM#': ['420956120','420956123','420956124']}

# List of models
new_list_models = [
'Skandic LE 600 ACE',
'Skandic LE E-TEC 600R',
'Skandic SE ACE 900'

]

oem_numbers = ['420956120','420956123','420956124']

# Range of years
years = list(range(2023, 2024))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#       Make                  Model Vendor       MPN AD Item Number  \
# 0  SKI-DOO     Skandic LE 600 ACE   NACH  SM-07163        KX09400
# 1  SKI-DOO  Skandic LE E-TEC 600R   NACH  SM-07163        KX09400
# 2  SKI-DOO     Skandic SE ACE 900   NACH  SM-07163        KX09400
# 3  SKI-DOO     Skandic LE 600 ACE   NACH  SM-07163        KX09400
# 4  SKI-DOO  Skandic LE E-TEC 600R   NACH  SM-07163        KX09400
# 5  SKI-DOO     Skandic SE ACE 900   NACH  SM-07163        KX09400
# 6  SKI-DOO     Skandic LE 600 ACE   NACH  SM-07163        KX09400
# 7  SKI-DOO  Skandic LE E-TEC 600R   NACH  SM-07163        KX09400
# 8  SKI-DOO     Skandic SE ACE 900   NACH  SM-07163        KX09400
#
#                      Vendor Notes       NI#  REF#       OEM#  Year
# 0  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120  2023
# 1  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120  2023
# 2  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120  2023
# 3  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123  2023
# 4  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123  2023
# 5  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956123  2023
# 6  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124  2023
# 7  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124  2023
# 8  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124  2023

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Oil Filters\MERGE\Oilfilters_23skandic.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 
         'MPN': ['SM-07163'], 'AD Item Number': ['KX09400'], 
         'Vendor Notes': ['PAPER ELEMENT TYPE WITH O-RING'], 
         'NI#': ['SM-07163'], 'REF#': [pd.NA], 'OEM#': ['420956120','420956123','420956124']}

# List of models
new_list_models = [
'Grand Touring LE 4-TEC 1200',
'Grand Touring SE 4-TEC 1200',
'MX Z Sport 600 ACE',
'MX Z TNT 600 ACE',
'Skandic WT 600 ACE',
'Skandic SWT ACE 600',
'Expedition 1200 SE',
'Expedition LE 4-TEC 1200',
'Expedition Sport 600 ACE',
'Formula MX ZX',
'MX Z 1200 TNT'
]

oem_numbers = ['420956120','420956123','420956124']

# Range of years
years = list(range(2011, 2024))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
# Out:
#         Make                        Model Vendor       MPN AD Item Number  \
# 0    SKI-DOO  Grand Touring LE 4-TEC 1200   NACH  SM-07163        KX09400
# 1    SKI-DOO  Grand Touring SE 4-TEC 1200   NACH  SM-07163        KX09400
# 2    SKI-DOO           MX Z Sport 600 ACE   NACH  SM-07163        KX09400
# 3    SKI-DOO             MX Z TNT 600 ACE   NACH  SM-07163        KX09400
# 4    SKI-DOO           Skandic WT 600 ACE   NACH  SM-07163        KX09400
# ..       ...                          ...    ...       ...            ...
# 424  SKI-DOO           Expedition 1200 SE   NACH  SM-07163        KX09400
# 425  SKI-DOO     Expedition LE 4-TEC 1200   NACH  SM-07163        KX09400
# 426  SKI-DOO     Expedition Sport 600 ACE   NACH  SM-07163        KX09400
# 427  SKI-DOO                Formula MX ZX   NACH  SM-07163        KX09400
# 428  SKI-DOO                MX Z 1200 TNT   NACH  SM-07163        KX09400
#
#                        Vendor Notes       NI#  REF#       OEM#  Year
# 0    PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120  2011
# 1    PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120  2011
# 2    PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120  2011
# 3    PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120  2011
# 4    PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956120  2011
# ..                              ...       ...   ...        ...   ...
# 424  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124  2023
# 425  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124  2023
# 426  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124  2023
# 427  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124  2023
# 428  PAPER ELEMENT TYPE WITH O-RING  SM-07163  <NA>  420956124  2023
#
# [429 rows x 10 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\Oil Filters\MERGE\Oilfilters_1123tnt1200.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SKI-DOO'], 'Model': ['all models'], 'Vendor': ['NACH'], 
         'MPN': ['SM-07163'], 'AD Item Number': ['KX09400'], 
         'Vendor Notes': ['PAPER ELEMENT TYPE WITH O-RING'], 
         'NI#': ['SM-07163'], 'REF#': [pd.NA], 'OEM#': ['420956120','420956123','420956124']}

# List of models
new_list_models = [
'Grand Touring LE 4-TEC 1200',
'Grand Touring SE 4-TEC 1200',
'MX Z Sport 600 ACE',
'MX Z TNT 600 ACE',
'Skandic WT 600 ACE',
'Skandic SWT ACE 600',
'Expedition 1200 SE',
'Expedition LE 4-TEC 1200',
'Expedition Sport 600 ACE',
'Formula MX ZX',
'MX Z 1200 TNT'
]

oem_numbers = ['420956120','420956123','420956124']

# Range of years
years = list(range(2011, 2024))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
print(final_df)
